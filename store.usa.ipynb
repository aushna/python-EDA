# %%
63import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
import os

# %%
import pandas as pd

# Path to your CSV file
file_path = r"C:\Users\User\Documents\power bi projects\Superstore_USA.csv"

# Try reading the CSV with different encodings
try:
    dataset = pd.read_csv(file_path, encoding='utf-8')  # Most common
except UnicodeDecodeError:
    dataset = pd.read_csv(file_path, encoding='latin-1')  # Try Latin-1 (ISO-8859-1)
except Exception as e:
    print(f"Error: {e}")

# Display the first 5 rows of the dataset
print(dataset.head(5))
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#     Region State or Province       City  Postal Code  Order Date   Ship Date  \
# ...

# %%
dataset.shape
# Out:
# (9426, 24)

# %%
#dataset.isnull().sum()
# Out:
# Row ID                  0
# Order Priority          0
# Discount                0
# Unit Price              0
# Shipping Cost           0
# Customer ID             0
# Customer Name           0
# Ship Mode               0
# Customer Segment        0
# Product Category        0
# Product Sub-Category    0
# Product Container       0
# Product Name            0
# Product Base Margin     0
# Region                  0
# State or Province       0
# City                    0
# Postal Code             0
# Order Date              0
# Ship Date               0
# Profit                  0
# Quantity ordered new    0
# Sales                   0
# Order ID                0
# dtype: int64

# %%
dataset.shape
# Out:
# (9426, 24)

# %% [markdown]
#  # ORDER PRIORITY

# %%
#dataset["Order Priority"].value_counts()
# Out:
# Order Priority
# High             1970
# Low              1926
# Not Specified    1881
# Medium           1844
# Critical         1805
# Name: count, dtype: int64

# %% [markdown]
# # SUB-Category of Product

# %%
plt.figure(figsize=(10,6))
sns.countplot(x="Product Category", data=dataset[dataset["Product Category"]=="Office Supplies"],hue="Product Sub-Category")
plt.title("Count of Sub Catoegory")
plt.savefig("Count of Sub Category.jpg")
plt.show()

# %% [markdown]
# # Top Five Province

# %%
# Get the top 5 provinces
top_provinces = dataset["State or Province"].value_counts().index[:5]

# Print the top 5 provinces
print(top_provinces)
# Out:
# Index(['California', 'Texas', 'Illinois', 'New York', 'Florida'], dtype='object', name='State or Province')

# %%
#dataset["Order Priority"].unique()
# Out:
# array(['Not Specified', 'High', 'Medium', 'Low', 'Critical', 'Critical '],
#       dtype=object)

# %% [markdown]
# # PROFIT IN PRODUCT CATEGORY

# %%
plt.figure(figsize=(5,4))
sns.barplot(x="Product Category",y="Profit",data=dataset)
plt.title("Profit in Product Catogery")
plt.savefig("Profit in product.jpg")
plt.show()

# %%
top_provinces = dataset["State or Province"].value_counts().index[:5]
top_provinces = ["California', 'Texas', 'Illinois', 'New York', 'Florida"]
filtered_data = dataset[dataset["State or Province"].isin(top_provinces)]

# %%
#dataset["Order Priority"]=dataset["Order Priority"].replace('Critical ', 'Critical')

# %%
dataset["Product Base Margin"].fillna(dataset["Product Base Margin"].mean(),inplace=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_21304\1305928458.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["Product Base Margin"].fillna(dataset["Product Base Margin"].mean(),inplace=True)

# %% [markdown]
# # #SHIP MODE

# %%
dataset["Ship Mode"].value_counts()
# Out:
# Ship Mode
# Regular Air       7036
# Delivery Truck    1283
# Express Air       1107
# Name: count, dtype: int64

# %%
x=dataset["Ship Mode"].value_counts().index
y=dataset["Ship Mode"].value_counts().values

# %% [markdown]
# PIE CHART** **

# %%
plt.figure(figsize=(5,4))
plt.pie(y,labels=x,startangle=60,autopct="%0.2f%%")
plt.legend(loc=2)
plt.show()
plt.title("Pie of Ship Mode")
plt.savefig("Pie Of Ship Mode.jpg")

# %% [markdown]
# # Product Category

# %%
plt.figure(figsize=(5,4))
sns.countplot(x="Ship Mode",data=dataset,hue="Product Category")
plt.title("Total Ship Category")
plt.savefig("Total Ship Category.jpg")
plt.show()

# %% [markdown]
# # Product Category

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="Product Category",data=dataset)
plt.title("Product Category")
plt.savefig("Product Category.jpg")
plt.show()
